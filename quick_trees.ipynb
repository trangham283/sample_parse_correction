# %%
from nltk.tree import Tree
from nltk.draw.tree import TreeView
from IPython.display import display

# %%
tree_str = "(ROOT (S (NP (NNS traders)) (VP (VBD said) (SBAR (S (NP (NP (JJS most)) (PP (IN of) (NP (PRP$ their) (JJ major) (JJ institutional) (NNS investors)))) (PP (IN on) (NP (DT the) (JJ other) (NN hand))) (VP (VBD sat) (ADJP (NN tight))))))))"

this_tree = Tree.fromstring(tree_str)
display(this_tree)
# Out:
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('NNS', ['traders'])]), Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NP', [Tree('JJS', ['most'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('PRP$', ['their']), Tree('JJ', ['major']), Tree('JJ', ['institutional']), Tree('NNS', ['investors'])])])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['other']), Tree('NN', ['hand'])])]), Tree('VP', [Tree('VBD', ['sat']), Tree('ADJP', [Tree('NN', ['tight'])])])])])])])])
